# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulwadood-64/ABDUL-WADOOD-/blob/main/MVIT_BATCH_3%7C%7CA%7C%26ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#comment
print("hello world")
# Out:
# hello world
